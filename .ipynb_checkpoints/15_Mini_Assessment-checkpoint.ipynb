# %% [markdown]
# # Notebook 15 – EDA Mini Assessment
#
# This notebook is a self-assessment covering the concepts and skills used in the previous EDA notebooks.
#
# **Structure:**
# - **Part A – Conceptual Questions:** answer each question in the markdown cell provided below it.
# - **Part B – Coding Exercises:** complete each exercise in the empty code cell provided, using the `telecom_customer_churn.csv` dataset.
#
# No solutions are included — this is meant to be filled in as practice.

# %%
# Run this cell first to load the dataset used throughout the exercises.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')

df = pd.read_csv('telecom_customer_churn.csv')
df.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure_months  \
# 0  CUST-10681    Male               0     Yes         No           24.0
# 1  CUST-10024  Female               0     Yes         No           35.0
# 2  CUST-10621    Male               0     Yes         No           68.0
# 3  CUST-10099    Male               0     Yes        Yes           18.0
# 4  CUST-10284    Male               1     Yes        Yes           34.0
#
#   phone_service internet_service        contract paperless_billing  \
# 0           Yes      Fiber optic  Month-to-month               Yes
# 1           Yes      Fiber optic  Month-to-month               Yes
# 2           Yes              DSL  Month-to-month               Yes
# 3           Yes      Fiber optic  Month-to-month               Yes
# 4           Yes               No  Month-to-month                No
#
#      payment_method  monthly_charges  total_charges churn
# 0       Credit card            80.04        1900.19    No
# ...

# %% [markdown]
# ---
# ## Part A – Conceptual Questions
#
# Answer each question in the markdown cell below it (double-click the cell to edit).

# %% [markdown]
# **Q1. What is EDA (Exploratory Data Analysis)?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q2. Why is EDA performed before applying Machine Learning?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q3. What is the difference between univariate, bivariate, and multivariate analysis?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q4. How do you identify missing values in a dataset?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q5. How do you identify duplicate records in a dataset?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q6. What is an outlier?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q7. Explain the IQR (Interquartile Range) method for detecting outliers.**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q8. What is skewness, and what does a positive vs. negative skew tell you about a distribution?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q9. What is correlation, and what range of values can a correlation coefficient take?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q10. What is the difference between correlation and causation?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q11. What is multicollinearity, and why is it a problem for some models?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q12. How do you identify class imbalance in a target variable?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# **Q13. Why should outliers not always be removed?**

# %% [markdown]
# _Your answer here._

# %% [markdown]
# ---
# ## Part B – Coding Exercises
#
# Complete each exercise in the empty code cell below its instructions. Use the `df` DataFrame loaded above (`telecom_customer_churn.csv`).

# %% [markdown]
# **Exercise 1: Create a correlation heatmap**
#
# Using the numeric columns `tenure_months`, `monthly_charges`, `total_charges`, and `senior_citizen`, compute the correlation matrix and display it as a heatmap with annotated values.

# %%
# Your code here

# %% [markdown]
# **Exercise 2: Detect outliers using IQR**
#
# Write a function that takes a numeric pandas Series and returns the lower bound, upper bound, and the outlier values using the 1.5×IQR rule. Apply it to `total_charges`.

# %%
# Your code here

# %% [markdown]
# **Exercise 3: Analyze the distribution of a numerical feature**
#
# Choose one numeric column (e.g. `monthly_charges`) and plot its distribution using a histogram with a KDE curve. Report its skewness value.

# %%
# Your code here

# %% [markdown]
# **Exercise 4: Perform categorical analysis**
#
# For the `contract` column, print the count and percentage of each category, and visualize it with a bar/count plot.

# %%
# Your code here

# %% [markdown]
# **Exercise 5: Generate a complete EDA summary**
#
# Using everything practiced above, produce a short EDA summary (in a markdown cell) for this dataset covering: dataset shape, missing values, duplicates, key numeric findings, and one notable pattern involving the `churn` column. Write your code to gather the numbers first, then summarize your findings in a markdown cell below.

# %%
# Your code here to gather any numbers you need for the summary

# %% [markdown]
# _Your EDA summary here._
